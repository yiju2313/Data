# %% [markdown]
# <a href="https://colab.research.google.com/github/yiju2313/Data/blob/master/assessment_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("readr")
install.packages("ggplot2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(readr)
library(ggplot2)

# %%
covid19 <- read.csv("Weekly_Age_County_Gender_19CoV.csv")
str(covid19)
# Out:
# 'data.frame':	280 obs. of  8 variables:
#  $ 確定病名      : chr  "嚴重特殊傳染性肺炎" "嚴重特殊傳染性肺炎" "嚴重特殊傳染性肺炎" "嚴重特殊傳染性肺炎" ...
#  $ 發病年份      : int  2020 2020 2020 2020 2020 2020 2020 2020 2020 2020 ...
#  $ 發病週別      : int  10 10 10 10 10 10 10 10 10 10 ...
#  $ 縣市          : chr  "空值" "空值" "空值" "空值" ...
#  $ 性別          : chr  "F" "F" "F" "F" ...
#  $ 是否為境外移入: chr  "是" "是" "是" "是" ...
#  $ 年齡層        : chr  "15-19" "20-24" "25-29" "30-34" ...
#  $ 確定病例數    : int  1 3 2 1 2 1 3 2 1 1 ...

# %%
head(covid19, n = 20)
# Out:
#    確定病名           發病年份 發病週別 縣市   性別 是否為境外移入 年齡層
# 1  嚴重特殊傳染性肺炎 2020     10       空值   F    是             15-19
# 2  嚴重特殊傳染性肺炎 2020     10       空值   F    是             20-24
# 3  嚴重特殊傳染性肺炎 2020     10       空值   F    是             25-29
# 4  嚴重特殊傳染性肺炎 2020     10       空值   F    是             30-34
# 5  嚴重特殊傳染性肺炎 2020     10       空值   F    是             35-39
# 6  嚴重特殊傳染性肺炎 2020     10       空值   M    是             25-29
# 7  嚴重特殊傳染性肺炎 2020     10       空值   M    是             30-34
# 8  嚴重特殊傳染性肺炎 2020     10       空值   M    是             35-39
# 9  嚴重特殊傳染性肺炎 2020     10       空值   M    是             70+
# 10 嚴重特殊傳染性肺炎 2020     10       桃園市 F    否             25-29
# 11 嚴重特殊傳染性肺炎 2020     10       桃園市 M    否             20-24
# 12 嚴重特殊傳染性肺炎 2020     10       新北市 F    否             55-59
# 13 嚴重特殊傳染性肺炎 2020     11       台南市 F    否             25-29
# 14 嚴重特殊傳染性肺炎 2020     11       空值   F    是             15-19
# 15 嚴重特殊傳染性肺炎 2020     11       空值   F    是             20-24
# ...

# %%
install.packages("showtext")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘sysfonts’, ‘showtextdb’

# %%
library(showtext)
# Out:
# Loading required package: sysfonts
#
# Loading required package: showtextdb

# %%
showtext.auto(enable = TRUE)
# Out:
# 'showtext.auto()' is now renamed to 'showtext_auto()'
# The old version still works, but consider using the new function in future code

# %%
ggplot(covid19, aes(x = 縣市)) + geom_bar()
# Out:
# plot without title

# %%
ggplot(covid19, aes(x = 年齡層, y = 發病週別)) + geom_boxplot()
# Out:
# plot without title

# %%
qplot(發病週別, 確定病例數, data=covid19, color=性別)
# Out:
# plot without title

# %%
qplot(確定病例數, 發病週別, data=covid19, geom=c("point", "smooth"))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
#
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “pseudoinverse used at 0.88”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “neighborhood radius 1.12”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “reciprocal condition number  0”
# Warning message in simpleLoess(y, x, w, span, degree = degree, parametric = parametric, :
# “There are other near singularities as well. 1”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “pseudoinverse used at 0.88”
# Warning message in predLoess(object$y, object$x, newx = if (is.null(newdata)) object$x else if (is.data.frame(newdata)) as.matrix(model.frame(delete.response(terms(object)), :
# “neighborhood radius 1.12”
# ...
